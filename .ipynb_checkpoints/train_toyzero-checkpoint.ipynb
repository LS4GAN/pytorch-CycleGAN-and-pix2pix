# %%
# %load_ext autoreload
# %autoreload 2

import time
from options.train_options import TrainOptions
from data import create_dataset
from models import create_model
from util.visualizer import Visualizer

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib inline

# %%
# srun --unbuffered python train.py --dataroot ~/PROJs/GAN/datasets/ls4gan/toyzero_cropped/toyzero_2021-06-29_safi_U --name toyzero --dataset_mode toyzero --input_nc 1 --output_nc 1 --model cycle_gan --max_dataset_size 1000 --batch_size 32

# %% [markdown]
# ## Options

# %%
class options:
    def __init__(self):
        self.dataroot = '/sdcc/u/yhuang2/PROJs/GAN/datasets/ls4gan/toyzero_cropped/toyzero_2021-06-29_safi_U'
        self.name = 'toyzero_ipynb'
        self.gpu_ids = [0]
        self.checkpoints_dir = './checkpoints'
        self.model = 'cycle_gan'
        self.input_nc = 1
        self.output_nc = 1
        self.ngf = 64
        self.ndf = 64
        self.netD = 'basic'
        self.netG = 'resnet_9blocks'
        self.n_layers_D = 3
        self.norm = 'instance'
        self.init_type = 'normal'
        self.init_gain = 0.02
        self.no_dropout = True
        self.dataset_mode = 'toyzero'
        self.direction = 'AtoB'
        self.serial_batches = False
        self.num_threads = 1
        self.batch_size = 32
        self.load_size = 286
        self.crop_size = 256
        self.max_dataset_size = 1000
        self.preprocess = 'resize_and_crop'
        self.no_flip = False
        self.display_winsize = 256
        self.epoch = 'latest'
        self.load_iter = 0
        self.verbose = False
        self.suffix = ''
        self.display_freq = 400
        self.display_ncols = 4
        self.display_id = 1
        self.display_server = 'http://localhost'
        self.display_env = 'main'
        self.display_port = 8097
        self.update_html_freq = 1000
        self.print_freq = 100
        self.no_html = False
        self.save_latest_freq = 5000
        self.save_epoch_freq = 5
        self.save_by_iter = False
        self.continue_train = False
        self.epoch_count = 1
        self.phase = 'train'
        self.n_epochs = 200
        self.n_epochs_decay = 100
        self.beta1 = 0.5
        self.lr = 0.0002
        self.gan_mode = 'lsgan'
        self.pool_size = 50
        self.lr_policy = 'linear'
        self.lr_decay_iters = 50
        self.lambda_A = 10.0
        self.lambda_B = 10.0
        self.lambda_identity = 0.5
        self.isTrain = True
        
        assert (self.phase == 'train' and self.isTrain) or (self.phase == 'test' and not self.isTrain)
opt = options()

# %%
dataset = create_dataset(opt)
dataset_size = len(dataset)
print('The number of training images = %d' % dataset_size)

model = create_model(opt)      # create a model given opt.model and other options
model.setup(opt)   # regular setup: load and print networks; create schedulers
# Out:
# dataset [ToyzeroDataset] was created
# The number of training images = 1000
# /sdcc/u/yhuang2/miniconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py:474: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [CycleGANModel] was created
# ---------- Networks initialized -------------
# [Network G_A] Total number of parameters : 11.366 M
# [Network G_B] Total number of parameters : 11.366 M
# [Network D_A] Total number of parameters : 2.763 M
# [Network D_B] Total number of parameters : 2.763 M
# -----------------------------------------------

# %%
for epoch in range(opt.epoch_count, opt.n_epochs + opt.n_epochs_decay + 1):
    
    print(f'\nStart of epoch {epoch} / {opt.n_epochs + opt.n_epochs_decay}')
    
    # Train
    epoch_start_time = time.time()  # Epoch timer    
    for i, data in enumerate(dataset):  # Iter over minibatches
        model.set_input(data)         
        model.optimize_parameters()   # Feed forward and backpropagation
    
    # Print loss and save model
    losses = model.get_current_losses()
    print(f"\tDiscriminator loss:\tD_A={losses['D_A']:.6f}, \tD_B={losses['D_B']:.6f}")
    print(f"\tGenerator loss:\t\tG_A={losses['G_A']:.6f}, \tG_A={losses['G_B']:.6f}")
    print(f"\tCycle loss:\t\tC_A={losses['cycle_A']:.6f}, \tC_B={losses['cycle_B']:.6f}")
    print(f"\tIdentity loss:\t\tI_A={losses['idt_A']:.6f}, \tI_B={losses['idt_B']:.6f}")
    print(f'\tTime Taken:\t\t{time.time() - epoch_start_time:.0f} sec')
    
    if epoch % opt.save_epoch_freq == 0:              # cache our model every <save_epoch_freq> epochs
        print(f'\tSaving models at the end of epoch {epoch}')
        model.save_networks('latest')
        model.save_networks(epoch)

    # Update learning rate
    model.update_learning_rate()
# Out:
# Start of epoch 1 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.249824, 	D_B=0.247227
# 	Generator loss:		G_A=0.297546, 	G_A=0.340953
# 	Cycle loss:		C_A=0.996339, 	C_B=0.681154
# 	Identity loss:		I_A=0.316577, 	I_B=0.470022
# 	Time Taken:		30 sec
#
# Start of epoch 2 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.237932, 	D_B=0.253815
# 	Generator loss:		G_A=0.275852, 	G_A=0.337387
# 	Cycle loss:		C_A=1.189559, 	C_B=0.720080
# 	Identity loss:		I_A=0.340714, 	I_B=0.580133
# 	Time Taken:		30 sec
#
# Start of epoch 3 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.195192, 	D_B=0.411453
# 	Generator loss:		G_A=0.370902, 	G_A=0.498405
# 	Cycle loss:		C_A=0.554142, 	C_B=0.613666
# 	Identity loss:		I_A=0.287673, 	I_B=0.260409
# 	Time Taken:		30 sec
#
# Start of epoch 4 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.241510, 	D_B=0.216801
# 	Generator loss:		G_A=0.368453, 	G_A=0.328790
# 	Cycle loss:		C_A=0.833381, 	C_B=0.598784
# 	Identity loss:		I_A=0.293082, 	I_B=0.403920
# 	Time Taken:		30 sec
#
# Start of epoch 5 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.243223, 	D_B=0.238091
# 	Generator loss:		G_A=0.305946, 	G_A=0.300557
# 	Cycle loss:		C_A=0.707142, 	C_B=0.609924
# 	Identity loss:		I_A=0.268727, 	I_B=0.323160
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 5
#
# Start of epoch 6 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.211340, 	D_B=0.276798
# 	Generator loss:		G_A=0.276396, 	G_A=0.416838
# 	Cycle loss:		C_A=1.413404, 	C_B=0.620046
# 	Identity loss:		I_A=0.297562, 	I_B=0.668874
# 	Time Taken:		30 sec
#
# Start of epoch 7 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.208571, 	D_B=0.248379
# 	Generator loss:		G_A=0.370779, 	G_A=0.359414
# 	Cycle loss:		C_A=0.494953, 	C_B=0.602141
# 	Identity loss:		I_A=0.280597, 	I_B=0.231415
# 	Time Taken:		30 sec
#
# Start of epoch 8 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.202613, 	D_B=0.226081
# 	Generator loss:		G_A=0.327311, 	G_A=0.368032
# 	Cycle loss:		C_A=0.504147, 	C_B=0.574716
# 	Identity loss:		I_A=0.277735, 	I_B=0.243632
# 	Time Taken:		30 sec
#
# Start of epoch 9 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.226208, 	D_B=0.218329
# 	Generator loss:		G_A=0.330556, 	G_A=0.305269
# 	Cycle loss:		C_A=1.273279, 	C_B=0.546278
# 	Identity loss:		I_A=0.246427, 	I_B=0.601865
# 	Time Taken:		30 sec
#
# Start of epoch 10 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.244757, 	D_B=0.190821
# 	Generator loss:		G_A=0.460775, 	G_A=0.425346
# 	Cycle loss:		C_A=0.820602, 	C_B=0.501098
# 	Identity loss:		I_A=0.232631, 	I_B=0.409087
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 10
#
# Start of epoch 11 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.333254, 	D_B=0.222637
# 	Generator loss:		G_A=0.461134, 	G_A=0.296856
# 	Cycle loss:		C_A=0.586996, 	C_B=0.583969
# 	Identity loss:		I_A=0.262615, 	I_B=0.268670
# 	Time Taken:		30 sec
#
# Start of epoch 12 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.185802, 	D_B=0.184570
# 	Generator loss:		G_A=0.379335, 	G_A=0.320809
# 	Cycle loss:		C_A=0.449452, 	C_B=0.566499
# 	Identity loss:		I_A=0.275144, 	I_B=0.224023
# 	Time Taken:		30 sec
#
# Start of epoch 13 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.214969, 	D_B=0.317079
# 	Generator loss:		G_A=0.326691, 	G_A=0.499620
# 	Cycle loss:		C_A=0.720932, 	C_B=0.599195
# 	Identity loss:		I_A=0.278131, 	I_B=0.344009
# 	Time Taken:		30 sec
#
# Start of epoch 14 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.210802, 	D_B=0.211224
# 	Generator loss:		G_A=0.411289, 	G_A=0.288804
# 	Cycle loss:		C_A=0.553455, 	C_B=0.516963
# 	Identity loss:		I_A=0.236293, 	I_B=0.250983
# 	Time Taken:		30 sec
#
# Start of epoch 15 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.202007, 	D_B=0.211865
# 	Generator loss:		G_A=0.313893, 	G_A=0.350367
# 	Cycle loss:		C_A=0.526370, 	C_B=0.449154
# 	Identity loss:		I_A=0.212614, 	I_B=0.254127
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 15
#
# Start of epoch 16 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.251662, 	D_B=0.213571
# 	Generator loss:		G_A=0.321329, 	G_A=0.487703
# 	Cycle loss:		C_A=0.645731, 	C_B=0.464471
# 	Identity loss:		I_A=0.224279, 	I_B=0.314752
# 	Time Taken:		30 sec
#
# Start of epoch 17 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.308359, 	D_B=0.209955
# 	Generator loss:		G_A=0.502694, 	G_A=0.263720
# 	Cycle loss:		C_A=0.588619, 	C_B=0.462562
# 	Identity loss:		I_A=0.220496, 	I_B=0.274839
# 	Time Taken:		30 sec
#
# Start of epoch 18 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.215674, 	D_B=0.192327
# 	Generator loss:		G_A=0.500689, 	G_A=0.301327
# 	Cycle loss:		C_A=0.911464, 	C_B=0.497713
# 	Identity loss:		I_A=0.236217, 	I_B=0.442397
# 	Time Taken:		30 sec
#
# Start of epoch 19 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.234800, 	D_B=0.171832
# 	Generator loss:		G_A=0.413584, 	G_A=0.476338
# 	Cycle loss:		C_A=1.790095, 	C_B=0.469368
# 	Identity loss:		I_A=0.203910, 	I_B=0.867270
# 	Time Taken:		30 sec
#
# Start of epoch 20 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.164220, 	D_B=0.215466
# 	Generator loss:		G_A=0.374159, 	G_A=0.665057
# 	Cycle loss:		C_A=0.772004, 	C_B=0.452575
# 	Identity loss:		I_A=0.207568, 	I_B=0.369130
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 20
#
# Start of epoch 21 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.335167, 	D_B=0.162311
# 	Generator loss:		G_A=0.504776, 	G_A=0.369497
# 	Cycle loss:		C_A=0.568795, 	C_B=0.493261
# 	Identity loss:		I_A=0.229809, 	I_B=0.273568
# 	Time Taken:		30 sec
#
# Start of epoch 22 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.263048, 	D_B=0.320140
# 	Generator loss:		G_A=0.242422, 	G_A=0.434149
# 	Cycle loss:		C_A=0.684471, 	C_B=0.415924
# 	Identity loss:		I_A=0.180115, 	I_B=0.330478
# 	Time Taken:		30 sec
#
# Start of epoch 23 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.246889, 	D_B=0.193595
# 	Generator loss:		G_A=0.265346, 	G_A=0.487431
# 	Cycle loss:		C_A=1.025204, 	C_B=0.402300
# 	Identity loss:		I_A=0.174281, 	I_B=0.452868
# 	Time Taken:		30 sec
#
# Start of epoch 24 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.232999, 	D_B=0.259711
# 	Generator loss:		G_A=0.249379, 	G_A=0.453544
# 	Cycle loss:		C_A=0.442762, 	C_B=0.389827
# 	Identity loss:		I_A=0.179314, 	I_B=0.204104
# 	Time Taken:		30 sec
#
# Start of epoch 25 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.250483, 	D_B=0.328510
# 	Generator loss:		G_A=0.292410, 	G_A=0.629996
# 	Cycle loss:		C_A=0.415256, 	C_B=0.428977
# 	Identity loss:		I_A=0.206316, 	I_B=0.206325
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 25
#
# Start of epoch 26 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.255826, 	D_B=0.230642
# 	Generator loss:		G_A=0.274281, 	G_A=0.299268
# 	Cycle loss:		C_A=0.473857, 	C_B=0.401923
# 	Identity loss:		I_A=0.181442, 	I_B=0.216198
# 	Time Taken:		30 sec
#
# Start of epoch 27 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.226784, 	D_B=0.203987
# 	Generator loss:		G_A=0.281308, 	G_A=0.539455
# 	Cycle loss:		C_A=0.488711, 	C_B=0.340632
# 	Identity loss:		I_A=0.160367, 	I_B=0.220776
# 	Time Taken:		30 sec
#
# Start of epoch 28 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.229731, 	D_B=0.287894
# 	Generator loss:		G_A=0.260466, 	G_A=0.538675
# 	Cycle loss:		C_A=1.015105, 	C_B=0.450161
# 	Identity loss:		I_A=0.216623, 	I_B=0.492019
# 	Time Taken:		30 sec
#
# Start of epoch 29 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.244202, 	D_B=0.336755
# 	Generator loss:		G_A=0.232176, 	G_A=0.727330
# 	Cycle loss:		C_A=0.714698, 	C_B=0.390173
# 	Identity loss:		I_A=0.181222, 	I_B=0.352276
# 	Time Taken:		30 sec
#
# Start of epoch 30 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.236238, 	D_B=0.207509
# 	Generator loss:		G_A=0.239257, 	G_A=0.433037
# 	Cycle loss:		C_A=0.677744, 	C_B=0.371330
# 	Identity loss:		I_A=0.166286, 	I_B=0.329049
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 30
#
# Start of epoch 31 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.204291, 	D_B=0.234827
# 	Generator loss:		G_A=0.312036, 	G_A=0.394532
# 	Cycle loss:		C_A=1.217763, 	C_B=0.346612
# 	Identity loss:		I_A=0.158922, 	I_B=0.606108
# 	Time Taken:		30 sec
#
# Start of epoch 32 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.200729, 	D_B=0.188971
# 	Generator loss:		G_A=0.328021, 	G_A=0.269094
# 	Cycle loss:		C_A=1.053855, 	C_B=0.393715
# 	Identity loss:		I_A=0.182494, 	I_B=0.485027
# 	Time Taken:		30 sec
#
# Start of epoch 33 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.221230, 	D_B=0.211617
# 	Generator loss:		G_A=0.324529, 	G_A=0.590197
# 	Cycle loss:		C_A=0.431937, 	C_B=0.444042
# 	Identity loss:		I_A=0.213473, 	I_B=0.205823
# 	Time Taken:		30 sec
#
# Start of epoch 34 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.242952, 	D_B=0.196140
# 	Generator loss:		G_A=0.273666, 	G_A=0.358165
# 	Cycle loss:		C_A=0.400680, 	C_B=0.352546
# 	Identity loss:		I_A=0.158813, 	I_B=0.185528
# 	Time Taken:		30 sec
#
# Start of epoch 35 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.202140, 	D_B=0.263438
# 	Generator loss:		G_A=0.320351, 	G_A=0.438097
# 	Cycle loss:		C_A=0.494868, 	C_B=0.421774
# 	Identity loss:		I_A=0.185026, 	I_B=0.229816
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 35
#
# Start of epoch 36 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.192833, 	D_B=0.164983
# 	Generator loss:		G_A=0.355978, 	G_A=0.467303
# 	Cycle loss:		C_A=0.415373, 	C_B=0.324634
# 	Identity loss:		I_A=0.151654, 	I_B=0.192196
# 	Time Taken:		30 sec
#
# Start of epoch 37 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.247540, 	D_B=0.186762
# 	Generator loss:		G_A=0.218774, 	G_A=0.302326
# 	Cycle loss:		C_A=0.563531, 	C_B=0.373114
# 	Identity loss:		I_A=0.180546, 	I_B=0.259750
# 	Time Taken:		30 sec
#
# Start of epoch 38 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.211198, 	D_B=0.224342
# 	Generator loss:		G_A=0.273950, 	G_A=0.392423
# 	Cycle loss:		C_A=0.585668, 	C_B=0.344334
# 	Identity loss:		I_A=0.143863, 	I_B=0.275266
# 	Time Taken:		30 sec
#
# Start of epoch 39 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.201290, 	D_B=0.203083
# 	Generator loss:		G_A=0.330246, 	G_A=0.343272
# 	Cycle loss:		C_A=0.432266, 	C_B=0.364616
# 	Identity loss:		I_A=0.177452, 	I_B=0.205440
# 	Time Taken:		30 sec
#
# Start of epoch 40 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.304267, 	D_B=0.217485
# 	Generator loss:		G_A=0.409954, 	G_A=0.568806
# 	Cycle loss:		C_A=0.454100, 	C_B=0.386508
# 	Identity loss:		I_A=0.178690, 	I_B=0.221436
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 40
#
# Start of epoch 41 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.161140, 	D_B=0.169867
# 	Generator loss:		G_A=0.396388, 	G_A=0.490558
# 	Cycle loss:		C_A=0.466511, 	C_B=0.342741
# 	Identity loss:		I_A=0.154691, 	I_B=0.238258
# 	Time Taken:		30 sec
#
# Start of epoch 42 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.206135, 	D_B=0.169701
# 	Generator loss:		G_A=0.295281, 	G_A=0.410092
# 	Cycle loss:		C_A=0.601764, 	C_B=0.402918
# 	Identity loss:		I_A=0.177299, 	I_B=0.274018
# 	Time Taken:		30 sec
#
# Start of epoch 43 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.223190, 	D_B=0.272900
# 	Generator loss:		G_A=0.330395, 	G_A=0.362988
# 	Cycle loss:		C_A=0.359854, 	C_B=0.430770
# 	Identity loss:		I_A=0.204563, 	I_B=0.170563
# 	Time Taken:		30 sec
#
# Start of epoch 44 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.188835, 	D_B=0.188821
# 	Generator loss:		G_A=0.300814, 	G_A=0.333568
# 	Cycle loss:		C_A=0.337241, 	C_B=0.352839
# 	Identity loss:		I_A=0.163193, 	I_B=0.164199
# 	Time Taken:		30 sec
#
# Start of epoch 45 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.224822, 	D_B=0.190052
# 	Generator loss:		G_A=0.343814, 	G_A=0.399966
# 	Cycle loss:		C_A=0.399431, 	C_B=0.338479
# 	Identity loss:		I_A=0.155370, 	I_B=0.203534
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 45
#
# Start of epoch 46 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.196743, 	D_B=0.306595
# 	Generator loss:		G_A=0.356019, 	G_A=0.299415
# 	Cycle loss:		C_A=0.578627, 	C_B=0.473582
# 	Identity loss:		I_A=0.200174, 	I_B=0.268476
# 	Time Taken:		30 sec
#
# Start of epoch 47 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.195256, 	D_B=0.235561
# 	Generator loss:		G_A=0.321800, 	G_A=0.283075
# 	Cycle loss:		C_A=1.440647, 	C_B=0.401466
# 	Identity loss:		I_A=0.182280, 	I_B=0.739609
# 	Time Taken:		30 sec
#
# Start of epoch 48 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.237666, 	D_B=0.257180
# 	Generator loss:		G_A=0.352218, 	G_A=0.286668
# 	Cycle loss:		C_A=0.520136, 	C_B=0.437736
# 	Identity loss:		I_A=0.207459, 	I_B=0.247187
# 	Time Taken:		30 sec
#
# Start of epoch 49 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.230776, 	D_B=0.254155
# 	Generator loss:		G_A=0.317179, 	G_A=0.295206
# 	Cycle loss:		C_A=0.540358, 	C_B=0.408343
# 	Identity loss:		I_A=0.195751, 	I_B=0.302639
# 	Time Taken:		30 sec
#
# Start of epoch 50 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.226929, 	D_B=0.214768
# 	Generator loss:		G_A=0.331793, 	G_A=0.293124
# 	Cycle loss:		C_A=0.484763, 	C_B=0.310207
# 	Identity loss:		I_A=0.143045, 	I_B=0.243146
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 50
#
# Start of epoch 51 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.193968, 	D_B=0.254985
# 	Generator loss:		G_A=0.240156, 	G_A=0.290395
# 	Cycle loss:		C_A=0.859950, 	C_B=0.357358
# 	Identity loss:		I_A=0.163839, 	I_B=0.424086
# 	Time Taken:		30 sec
#
# Start of epoch 52 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.227306, 	D_B=0.246091
# 	Generator loss:		G_A=0.303546, 	G_A=0.291151
# 	Cycle loss:		C_A=0.462483, 	C_B=0.357192
# 	Identity loss:		I_A=0.168780, 	I_B=0.233994
# 	Time Taken:		30 sec
#
# Start of epoch 53 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.184539, 	D_B=0.296722
# 	Generator loss:		G_A=0.391243, 	G_A=0.291332
# 	Cycle loss:		C_A=0.538671, 	C_B=0.307813
# 	Identity loss:		I_A=0.139350, 	I_B=0.258772
# 	Time Taken:		30 sec
#
# Start of epoch 54 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.185105, 	D_B=0.232811
# 	Generator loss:		G_A=0.363366, 	G_A=0.297018
# 	Cycle loss:		C_A=0.552353, 	C_B=0.342517
# 	Identity loss:		I_A=0.156779, 	I_B=0.282307
# 	Time Taken:		30 sec
#
# Start of epoch 55 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.176998, 	D_B=0.223005
# 	Generator loss:		G_A=0.308843, 	G_A=0.292794
# 	Cycle loss:		C_A=0.446136, 	C_B=0.314870
# 	Identity loss:		I_A=0.139567, 	I_B=0.217441
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 55
#
# Start of epoch 56 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.207155, 	D_B=0.259806
# 	Generator loss:		G_A=0.257002, 	G_A=0.287289
# 	Cycle loss:		C_A=0.644459, 	C_B=0.384462
# 	Identity loss:		I_A=0.181040, 	I_B=0.298178
# 	Time Taken:		30 sec
#
# Start of epoch 57 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.168012, 	D_B=0.246828
# 	Generator loss:		G_A=0.342897, 	G_A=0.282701
# 	Cycle loss:		C_A=0.447242, 	C_B=0.359235
# 	Identity loss:		I_A=0.170741, 	I_B=0.227643
# 	Time Taken:		30 sec
#
# Start of epoch 58 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.225014, 	D_B=0.242463
# 	Generator loss:		G_A=0.389312, 	G_A=0.297165
# 	Cycle loss:		C_A=0.512633, 	C_B=0.324116
# 	Identity loss:		I_A=0.147371, 	I_B=0.239601
# 	Time Taken:		30 sec
#
# Start of epoch 59 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.215576, 	D_B=0.248197
# 	Generator loss:		G_A=0.197277, 	G_A=0.282829
# 	Cycle loss:		C_A=0.486612, 	C_B=0.325294
# 	Identity loss:		I_A=0.150127, 	I_B=0.243586
# 	Time Taken:		30 sec
#
# Start of epoch 60 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.182397, 	D_B=0.257087
# 	Generator loss:		G_A=0.288793, 	G_A=0.276181
# 	Cycle loss:		C_A=0.629263, 	C_B=0.360172
# 	Identity loss:		I_A=0.154393, 	I_B=0.295672
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 60
#
# Start of epoch 61 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.193121, 	D_B=0.230528
# 	Generator loss:		G_A=0.361954, 	G_A=0.283359
# 	Cycle loss:		C_A=0.507259, 	C_B=0.280353
# 	Identity loss:		I_A=0.129230, 	I_B=0.230433
# 	Time Taken:		30 sec
#
# Start of epoch 62 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.199155, 	D_B=0.228338
# 	Generator loss:		G_A=0.340001, 	G_A=0.274218
# 	Cycle loss:		C_A=0.345569, 	C_B=0.366418
# 	Identity loss:		I_A=0.179792, 	I_B=0.160938
# 	Time Taken:		30 sec
#
# Start of epoch 63 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.268257, 	D_B=0.226753
# 	Generator loss:		G_A=0.292588, 	G_A=0.293692
# 	Cycle loss:		C_A=0.375004, 	C_B=0.305051
# 	Identity loss:		I_A=0.138637, 	I_B=0.168624
# 	Time Taken:		30 sec
#
# Start of epoch 64 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.191200, 	D_B=0.228815
# 	Generator loss:		G_A=0.376858, 	G_A=0.305525
# 	Cycle loss:		C_A=0.511254, 	C_B=0.399703
# 	Identity loss:		I_A=0.175404, 	I_B=0.218994
# 	Time Taken:		30 sec
#
# Start of epoch 65 / 300
# 	Learning rate:		2.00e-04 -> 2.00e-04
# 	Discriminator loss:	D_A=0.154547, 	D_B=0.237373
# 	Generator loss:		G_A=0.408061, 	G_A=0.305023
# 	Cycle loss:		C_A=0.385340, 	C_B=0.316965
# 	Identity loss:		I_A=0.141549, 	I_B=0.186785
# 	Time Taken:		30 sec
# 	Saving models at the end of epoch 65
#
# Start of epoch 66 / 300

# %%
A = model.get_current_visuals()

# %%
def plot_results(visuals, num_samples=5):
    """
    
    """
    side = 3
    cmap = 'bwr'
    tensors = []
    keys = ['real_A', 'fake_A', 'idt_B', 'real_B', 'fake_B', 'idt_A']
    key_map = {
        'real_A': 'Real image from field A',
        'fake_A': 'Image translated from B to A ($G_{B->A}(b)$)',
        'idt_B': 'Image translated from A to A ($G_{B->A}(a)$)',
        'real_B': 'Real image from field B',
        'fake_B': 'Image translated from A to B ($G_{A->B}(a)$)',
        'idt_A': 'Image translated from B to B ($G_{A->B}(b)$)',
    }
    for key in keys:
        val = visuals[key]
        # print(key)
        indices = np.arange(len(val))
        indices = np.random.choice(indices, num_samples, replace=False)
        val = val[indices].cpu().detach().squeeze().numpy()
        
        fig, axes = plt.subplots(1, num_samples, figsize=(num_samples * side * 1.1, side))
        for i, (ax, image) in enumerate(zip(axes, val)):
            divnorm = mcolors.TwoSlopeNorm(vmin=image.min(), vcenter=0., vmax=image.max())
            ax.set_aspect(1)
            im = ax.pcolormesh(image, cmap=cmap, norm=divnorm)
            divider = make_axes_locatable(ax)
            cax = divider.append_axes('right', size='5%', pad=0.1)
            fig.colorbar(im, cax=cax, orientation='vertical')
        
        fig.suptitle(f"{key_map['key']}", fontsize=20)
        plt.tight_layout()
    
plot_results(A, num_samples=5)
